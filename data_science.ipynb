# %% [markdown]
# ### convert data to csv

# %%
import csv

data = [
    ["Duration", "Average_Pulse", "Max_Pulse", "Calorie_Burnage", "Hours_Work", "Hours_Sleep"],
    [30, 80, 120, 240, 10, 7],
    [45, 85, 120, 250, 10, 7],
    [45, 90, 130, 260, 8, 7],
    [60, 95, 130, 270, 8, 7],
    [60, 100, 140, 280, 0, 7],
    ["", "", "", "", "", ""],  # Empty row
    [60, 105, 140, 290, 7, 8],
    [60, 110, 145, 300, 7, 8],
    [45, "", "AF", "", 8, 8],  # "AF" is considered a string in this context
    [45, 115, 145, 310, 8, 8],
    [60, 120, 150, 320, 0, 8],
    [60, "9 000", 130, "", "", 8],  # "9 000" is considered a string in this context
    [45, 125, 150, 330, 8, 8]
]

file_path = r"C:\Users\s176444\Downloads\data\fitness_watch_data.csv"

try:
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(data)
    print("CSV file successfully created at:", file_path)
except Exception as e:
    print("Failed to create CSV file:", str(e))
# Out:
# CSV file successfully created at: C:\Users\s176444\Downloads\data\fitness_watch_data.csv

# %% [markdown]
# ### Read the data

# %%
import pandas as pd

df = pd.read_csv("fitness_watch_data.csv", header=0, sep=",")

df
# Out:
#     Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0       30.0            80       120            240.0        10.0          7.0
# 1       45.0            85       120            250.0        10.0          7.0
# 2       45.0            90       130            260.0         8.0          7.0
# 3       60.0            95       130            270.0         8.0          7.0
# 4       60.0           100       140            280.0         0.0          7.0
# 5        NaN           NaN       NaN              NaN         NaN          NaN
# 6       60.0           105       140            290.0         7.0          8.0
# 7       60.0           110       145            300.0         7.0          8.0
# 8       45.0           NaN        AF              NaN         8.0          8.0
# 9       45.0           115       145            310.0         8.0          8.0
# 10      60.0           120       150            320.0         0.0          8.0
# ...

# %% [markdown]
# ### Min max mean

# %%
# max_pluse_column = df["Max_Pulse"]

# %%
# # Convert the "Max_Pulse" column to numeric, ignoring errors
# df['Max_Pulse'] = pd.to_numeric(df['Max_Pulse'], errors='coerce')

# # Calculate the mean of the "Max_Pulse" column
# max_pulse_max = df['Max_Pulse'].max()

# # Print the mean
# print("Mean of Max_Pulse:", max_pulse_max)

# %%
# # Convert the "Max_Pulse" column to numeric, ignoring errors
# df['Max_Pulse'] = pd.to_numeric(df['Max_Pulse'], errors='coerce')

# # Calculate the mean of the "Max_Pulse" column
# max_pulse_mean = df['Max_Pulse'].mean()

# # Print the mean
# print("Mean of Max_Pulse:", max_pulse_mean)

# %%
# # Convert the "Max_Pulse" column to numeric, ignoring errors
# df['Max_Pulse'] = pd.to_numeric(df['Max_Pulse'], errors='coerce')

# # Calculate the mean of the "Max_Pulse" column
# max_pulse_min = df['Max_Pulse'].min()

# # Print the mean
# print("Mean of Max_Pulse:", max_pulse_min)

# %% [markdown]
# ### Clean the data (remove all NaN)

# %%
df.dropna(axis=0,inplace=True)

# %%
# show the clean data
df
# Out:
#     Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0       30.0            80       120            240.0        10.0          7.0
# 1       45.0            85       120            250.0        10.0          7.0
# 2       45.0            90       130            260.0         8.0          7.0
# 3       60.0            95       130            270.0         8.0          7.0
# 4       60.0           100       140            280.0         0.0          7.0
# 6       60.0           105       140            290.0         7.0          8.0
# 7       60.0           110       145            300.0         7.0          8.0
# 9       45.0           115       145            310.0         8.0          8.0
# 10      60.0           120       150            320.0         0.0          8.0
# 12      45.0           125       150            330.0         8.0          8.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Duration         10 non-null     float64
#  1   Average_Pulse    10 non-null     object
#  2   Max_Pulse        10 non-null     object
#  3   Calorie_Burnage  10 non-null     float64
#  4   Hours_Work       10 non-null     float64
#  5   Hours_Sleep      10 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 560.0+ bytes

# %%
df["Average_Pulse"] = df["Average_Pulse"].astype(float)
df["Max_Pulse"] = df["Max_Pulse"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Duration         10 non-null     float64
#  1   Average_Pulse    10 non-null     float64
#  2   Max_Pulse        10 non-null     float64
#  3   Calorie_Burnage  10 non-null     float64
#  4   Hours_Work       10 non-null     float64
#  5   Hours_Sleep      10 non-null     float64
# dtypes: float64(6)
# memory usage: 560.0 bytes

# %%
df
# Out:
#     Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0       30.0           80.0      120.0            240.0        10.0
# 1       45.0           85.0      120.0            250.0        10.0
# 2       45.0           90.0      130.0            260.0         8.0
# 3       60.0           95.0      130.0            270.0         8.0
# 4       60.0          100.0      140.0            280.0         0.0
# 6       60.0          105.0      140.0            290.0         7.0
# 7       60.0          110.0      145.0            300.0         7.0
# 9       45.0          115.0      145.0            310.0         8.0
# 10      60.0          120.0      150.0            320.0         0.0
# 12      45.0          125.0      150.0            330.0         8.0
#
#     Hours_Sleep
# 0           7.0
# 1           7.0
# 2           7.0
# 3           7.0
# 4           7.0
# 6           8.0
# 7           8.0
# 9           8.0
# 10          8.0
# 12          8.0

# %%
df.describe().astype(float)
# Out:
#         Duration  Average_Pulse   Max_Pulse  Calorie_Burnage  Hours_Work  \
# count  10.000000      10.000000   10.000000        10.000000   10.000000
# mean   51.000000     102.500000  137.000000       285.000000    6.600000
# std    10.488088      15.138252   11.352924        30.276504    3.627059
# min    30.000000      80.000000  120.000000       240.000000    0.000000
# 25%    45.000000      91.250000  130.000000       262.500000    7.000000
# 50%    52.500000     102.500000  140.000000       285.000000    8.000000
# 75%    60.000000     113.750000  145.000000       307.500000    8.000000
# max    60.000000     125.000000  150.000000       330.000000   10.000000
#
#        Hours_Sleep
# count    10.000000
# mean      7.500000
# std       0.527046
# min       7.000000
# 25%       7.000000
# 50%       7.500000
# 75%       8.000000
# max       8.000000

# %% [markdown]
# ### plot the data (scatter)

# %%
df.plot(x ='Average_Pulse', y='Calorie_Burnage', kind='scatter'),
plt.ylim(ymin=0)
plt.xlim(xmin=0)

plt.show()

# %% [markdown]
# ### Find the slope : Slope = f(x2) - f(x1) / x2-x1

# %%
def  slope(x1,y1,x2,y2):
    s = (y2-y1)/(x2-x1)
    return s 

print(slope(80,240,90,260))
# Out:
# 2.0

# %%
# Slope = 2

# %% [markdown]
# ### find the Slope and Intercept Using Python: The np.polyfit() function returns the slope and intercept.

# %%
x = df["Average_Pulse"]
y = df["Calorie_Burnage"]
slope_intercept = np.polyfit(x,y,1)

print(slope_intercept)
# Out:
# [ 2. 80.]
